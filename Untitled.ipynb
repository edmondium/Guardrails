# %%
# !pwd
# Out:
# /workspace

# %%
# !ls /*
# Out:
# /environment  /singularity
#
# /bin:
# '['				    mount
#  aclocal			    mountpoint
#  aclocal-1.16			    mtrace
#  addpart			    mv
#  addr2line			    namei
#  apt				    nano
#  apt-cache			    nasm
#  apt-cdrom			    nawk
#  apt-config			    ncurses5-config
#  apt-extracttemplates		    ncurses6-config
#  apt-ftparchive			    ncursesw5-config
#  apt-get			    ncursesw6-config
#  apt-key			    ndisasm
#  apt-mark			    newgrp
#  apt-sortpkgs			    nice
#  ar				    ninja
#  arch				    nisdomainname
#  as				    nl
#  autoconf			    nm
#  autoheader			    nohup
#  autom4te			    nproc
#  automake			    nsenter
#  automake-1.16			    numactl
#  autoreconf			    numastat
#  autoscan			    numfmt
#  autoupdate			    nv-fabricmanager
#  awk				    nvbench-ctl
#  b2sum				    nvidia-cuda-mps-control
#  base32				    nvidia-cuda-mps-server
#  base64				    nvidia-debugdump
#  basename			    nvidia-modprobe
#  bash				    nvidia-persistenced
#  bashbug			    nvidia-smi
# ...

# %%
# !cp /
